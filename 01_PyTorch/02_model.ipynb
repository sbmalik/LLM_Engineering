# %%
import torch

# %%
class TestModel(torch.nn.Module):

    def __init__(self, ip_dims, out_dims):
        super().__init__()
        self.layers = torch.nn.Sequential(
            torch.nn.Linear(ip_dims, 30),
            torch.nn.ReLU(),
            torch.nn.Linear(30, 10),
            torch.nn.ReLU(),
            torch.nn.Linear(10, out_dims),
        )

    def forward(self, ips):
        return self.layers(ips)

# %%
ips = torch.rand(1, 10)
ips.shape
# Out:
# torch.Size([1, 10])

# %%
test_model = TestModel(10, 3)
test_model
# Out:
# TestModel(
#   (layers): Sequential(
#     (0): Linear(in_features=10, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=3, bias=True)
#   )
# )

# %%
print(test_model(ips))
with torch.no_grad():
    print(test_model(ips))
# Out:
# tensor([[ 0.2706,  0.0006, -0.1547]], grad_fn=<AddmmBackward0>)
# tensor([[ 0.2706,  0.0006, -0.1547]])

# %%
trainable_param_count = 0
for p in test_model.parameters():
    if p.requires_grad == False:
        print(p)
    else:
        trainable_param_count += p.numel()

print(trainable_param_count)
# Out:
# 673

# %%
test_model.layers[0].weight.shape # mm 
test_model.layers[0].bias.shape # Add
# Out:
# torch.Size([30])

# %%
torch.nn.Linear(3, 2)(torch.nn.ReLU()(torch.nn.Linear(1, 3)(torch.tensor([[1.]]))))
# Out:
# tensor([[ 0.1447, -0.1717]], grad_fn=<AddmmBackward0>)

# %%
torch.tensor([[1.]]).shape
# Out:
# torch.Size([1, 1])

# %%
torch.tensor([1.]).shape
# Out:
# torch.Size([1])

# %%
x = torch.tensor([3.,], requires_grad=True)
y = x ** 2
y
# Out:
# tensor([9.], grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([6.])

# %%
torch.nn.Linear(1, 1).weight
torch.nn.Linear(1, 1).bias
# Out:
# Parameter containing:
# tensor([-0.2237], requires_grad=True)
