# %%
import torch

# %%
context_length = 4
pos_emb_layer = torch.nn.Embedding(context_length, 2)
pos_emb = pos_emb_layer(torch.arange(context_length))

# %%
pos_emb
# Out:
# tensor([[-1.7585,  1.1999],
#         [ 1.6699, -0.7892],
#         [-0.6406,  0.5127],
#         [ 1.0157, -1.2012]], grad_fn=<EmbeddingBackward0>)
